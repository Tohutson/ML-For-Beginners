# %% [markdown]
# # Welcome to the notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn import datasets, linear_model, model_selection
from sklearn.metrics import mean_squared_error, r2_score

# Load the diabetes dataset
X, y = datasets.load_diabetes(return_X_y=True)

# Print the shape of the data and the first row
print(X.shape)
print(X[0])
# Out:
# (442, 10)
# [ 0.03807591  0.05068012  0.06169621  0.02187239 -0.0442235  -0.03482076
#  -0.04340085 -0.00259226  0.01990749 -0.01764613]

# %%
#Extract colum at index 2
X = X[:, 0]
print(X.shape)

# Reshape to a 2D array
X = X.reshape((-1,1))
print(X.shape)
print(X)
# Out:
# (442,)
# (442, 1)
# [[ 0.03807591]
#  [-0.00188202]
#  [ 0.08529891]
#  [-0.08906294]
#  [ 0.00538306]
#  [-0.09269548]
#  [-0.04547248]
#  [ 0.06350368]
#  [ 0.04170844]
#  [-0.07090025]
#  [-0.09632802]
#  [ 0.02717829]
#  [ 0.01628068]
#  [ 0.00538306]
#  [ 0.04534098]
#  [-0.05273755]
#  [-0.00551455]
#  [ 0.07076875]
#  [-0.0382074 ]
#  [-0.02730979]
#  [-0.04910502]
#  [-0.0854304 ]
#  [-0.0854304 ]
#  [ 0.04534098]
#  [-0.06363517]
#  [-0.06726771]
#  [-0.10722563]
#  [-0.02367725]
#  [ 0.05260606]
#  [ 0.06713621]
#  [-0.06000263]
#  [-0.02367725]
#  [ 0.03444337]
#  [ 0.03081083]
#  [ 0.01628068]
#  [ 0.04897352]
#  [ 0.01264814]
#  [-0.00914709]
#  [-0.00188202]
#  [-0.00188202]
#  [ 0.00538306]
#  [-0.09996055]
#  [-0.06000263]
#  [ 0.01991321]
#  [ 0.04534098]
#  [ 0.02717829]
#  [-0.05637009]
#  [-0.07816532]
#  [ 0.06713621]
#  [-0.04183994]
#  [ 0.03444337]
#  [ 0.05987114]
#  [-0.05273755]
#  [-0.00914709]
#  [-0.04910502]
#  [-0.04183994]
#  [-0.04183994]
# ...

# %%
#Split data into training and testing data

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.33)

# %%
# Create linear regression model and train it with our data
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict using our test data
y_pred = model.predict(X_test)

# %%
# Create the scatter plot 
plt.scatter(X_test, y_test, color='black')

# Plot the predictions
plt.plot(X_test, y_pred, color='blue', linewidth=3)

# Add lables and a title
plt.xlabel('Age')
plt.ylabel('Disease Progression')
plt.title('Diabetes Prgression against BMI')

# Draw the plot
plt.show()
